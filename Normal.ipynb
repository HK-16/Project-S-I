# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.optimize as sco
plt.style.use('fivethirtyeight')
np.random.seed(777)
xrange=range
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
table = pd.read_excel('MASTER FILE.xlsx')

table = table.round(2)
print(table.dtypes)
table.set_index("Date", inplace = True)
display(table.head())
# Out:
# Date          datetime64[ns]
# AUROPHARMA           float64
# GLAXO                float64
# GLENMARK             float64
# ZYDUSLIFE            float64
# WIPRO                float64
# TECHM                float64
# BSOFT                float64
# HCLTECH              float64
# SUPRAJIT             float64
# BOSCHLTD             float64
# JAMNAAUTO            float64
# MAHSCOOTER           float64
# TCI                  float64
# SCI                  float64
# AEGISCHEM            float64
# GPPL                 float64
# NCC                  float64
# KNRCON               float64
# LT                   float64
# KALPATPOWR           float64
# dtype: object
#             AUROPHARMA    GLAXO  GLENMARK  ZYDUSLIFE   WIPRO   TECHM  BSOFT  \
# Date
# 2012-10-01       72.18  1001.58    417.70     170.06  143.51  256.39  68.87
# 2012-10-03       73.22   990.15    419.45     171.80  142.59  248.55  68.90
# 2012-10-04       72.35   976.05    407.00     166.07  143.59  242.95  67.63
# ...

# %%
plt.figure(figsize=(14, 7))
for c in table.columns.values:
    plt.plot(table.index, table[c], lw=3, alpha=0.8,label=c)
plt.legend(loc='upper left', fontsize=12)
plt.ylabel('price in $')
# Out:
# Text(0, 0.5, 'price in $')

# %%
returns = table.pct_change()
plt.figure(figsize=(14, 7))
for c in returns.columns.values:
    plt.plot(returns.index, returns[c], lw=3, alpha=0.8,label=c)
plt.legend(loc='upper right', fontsize=12)
plt.ylabel('Daily Returns')
# returns.to_excel('returns.xlsx')
# Out:
# Text(0, 0.5, 'Daily Returns')

# %%
plt.figure(figsize=(20, 10))

plt.plot(returns.index, returns['AUROPHARMA'], lw=3, alpha=0.8,label='AUROPHARMA')
plt.legend(loc='upper right', fontsize=12)
plt.ylabel('daily returns')

# %%
plt.figure(figsize=(20, 10))
plt.plot(returns.index, returns['GLAXO'], lw=3, alpha=0.8,label='GLAXO')
plt.legend(loc='upper right', fontsize=12)
plt.ylabel('daily returns')

# %%
plt.figure(figsize=(20, 10))
plt.plot(returns.index, returns['GLENMARK'], lw=3, alpha=0.8,label='GLENMARK')
plt.legend(loc='upper right', fontsize=12)
plt.ylabel('daily returns')

# %%
plt.figure(figsize=(30, 10))
plt.plot(returns.index, returns['ZYDUSLIFE'], lw=3, alpha=0.8,label='ZYDUSLIFE')
plt.legend(loc='upper right', fontsize=12)
plt.ylabel('daily returns')

# %%
plt.figure(figsize=(30, 10))
plt.plot(returns.index, returns['WIPRO'], lw=3, alpha=0.8,label='WIPRO')
plt.legend(loc='upper right', fontsize=12)
plt.ylabel('daily returns')

# %%
plt.figure(figsize=(30, 10))
plt.plot(returns.index, returns['TECHM'], lw=3, alpha=0.8,label='TECHM')
plt.legend(loc='upper right', fontsize=12)
plt.ylabel('daily returns')

# %%
plt.figure(figsize=(30, 10))
plt.plot(returns.index, returns['BSOFT'], lw=3, alpha=0.8,label='BSOFT')
plt.legend(loc='upper right', fontsize=12)
plt.ylabel('daily returns')

# %%
plt.figure(figsize=(30, 10))
plt.plot(returns.index, returns['HCLTECH'], lw=3, alpha=0.8,label='HCLTECH')
plt.legend(loc='upper right', fontsize=12)
plt.ylabel('daily returns')

# %%
plt.figure(figsize=(30, 10))
plt.plot(returns.index, returns['SUPRAJIT'], lw=3, alpha=0.8,label='SUPRAJIT')
plt.legend(loc='upper right', fontsize=12)
plt.ylabel('daily returns')

# %%
plt.figure(figsize=(30, 10))
plt.plot(returns.index, returns['JAMNAAUTO'], lw=3, alpha=0.8,label='JAMNAAUTO')
plt.legend(loc='upper right', fontsize=12)
plt.ylabel('daily returns')

# %%
plt.figure(figsize=(30, 10))
plt.plot(returns.index, returns['MAHSCOOTER'], lw=3, alpha=0.8,label='MAHSCOOTER')
plt.legend(loc='upper right', fontsize=12)
plt.ylabel('daily returns')

# %%
plt.figure(figsize=(30, 10))
plt.plot(returns.index, returns['BOSCHLTD'], lw=3, alpha=0.8,label='BOSCHLTD')
plt.legend(loc='upper right', fontsize=12)
plt.ylabel('daily returns')

# %%
plt.figure(figsize=(30, 10))
plt.plot(returns.index, returns['KNRCON'], lw=3, alpha=0.8,label='KNRCON')
plt.legend(loc='upper right', fontsize=12)
plt.ylabel('daily returns')

# %%
plt.figure(figsize=(30, 10))
plt.plot(returns.index, returns['NCC'], lw=3, alpha=0.8,label='NCC')
plt.legend(loc='upper right', fontsize=12)
plt.ylabel('daily returns')

# %%
plt.figure(figsize=(30, 10))
plt.plot(returns.index, returns['LT'], lw=3, alpha=0.8,label='LT')
plt.legend(loc='upper right', fontsize=12)
plt.ylabel('daily returns')

# %%
plt.figure(figsize=(30, 10))
plt.plot(returns.index, returns['KALPATPOWR'], lw=3, alpha=0.8,label='KALPATPOWR')
plt.legend(loc='upper right', fontsize=12)
plt.ylabel('daily returns')

# %%
plt.figure(figsize=(30, 10))
plt.plot(returns.index, returns['SCI'], lw=3, alpha=0.8,label='SCI')
plt.legend(loc='upper right', fontsize=12)
plt.ylabel('daily returns')

# %%
plt.figure(figsize=(30, 10))
plt.plot(returns.index, returns['AEGISCHEM'], lw=3, alpha=0.8,label='AEGISCHEM')
plt.legend(loc='upper right', fontsize=12)
plt.ylabel('daily returns')

# %%
plt.figure(figsize=(20, 10))
plt.plot(returns.index, returns['TCI'], lw=3, alpha=0.8,label='TCI')
plt.legend(loc='upper right', fontsize=12)
plt.ylabel('daily returns')

# %%
plt.figure(figsize=(20, 10))
plt.plot(returns.index, returns['GPPL'], lw=3, alpha=0.8,label='GPPL')
plt.legend(loc='upper right', fontsize=12)
plt.ylabel('daily returns')

# %%
def portfolio_annualised_performance(weights, mean_returns, cov_matrix):

    returns = np.sum(mean_returns* weights) *252
    std = np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights))) * np.sqrt(252)
    return std, returns
  
def random_portfolios(num_portfolios, mean_returns, cov_matrix, risk_free_rate):
    results = np.zeros((3,num_portfolios))
    weights_record = []
    for i in xrange(num_portfolios):
        weights = np.random.random(20)
        weights /= np.sum(weights)
        weights_record.append(weights)
        
        portfolio_std_dev, portfolio_return = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
        results[0,i] = portfolio_std_dev
        results[1,i] = portfolio_return
        results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev
    return results, weights_record

# %%
returns = table.pct_change()
mean_returns = returns.mean()
cov_matrix = returns.cov()

num_portfolios = 5000

# 10 yr GS as on 22 Nov 2022
risk_free_rate = 0.073201

# %%
def display_simulated_ef_with_random(mean_returns, cov_matrix, num_portfolios, risk_free_rate):
    results, weights = random_portfolios(num_portfolios,mean_returns, cov_matrix, risk_free_rate)
    
    max_sharpe_idx = np.argmax(results[2])
    sdp, rp = results[0,max_sharpe_idx], results[1,max_sharpe_idx]
    max_sharpe_allocation = pd.DataFrame(weights[max_sharpe_idx],index=table.columns,columns=['allocation'])
    max_sharpe_allocation.allocation = [round(i*100,2)for i in max_sharpe_allocation.allocation]
    max_sharpe_allocation = max_sharpe_allocation.T
    
    min_vol_idx = np.argmin(results[0])
    sdp_min, rp_min = results[0,min_vol_idx], results[1,min_vol_idx]
    min_vol_allocation = pd.DataFrame(weights[min_vol_idx],index=table.columns,columns=['allocation'])
    min_vol_allocation.allocation = [round(i*100,2)for i in min_vol_allocation.allocation]
    min_vol_allocation = min_vol_allocation.T
    
    print("-"*80)
    print("Maximum Sharpe Ratio Portfolio Allocation\n")
    print("Annualised Return: %", round(rp*100,2))
    print("Annualised Volatility: %", round(sdp*100,2))
    print("\n")
    print(max_sharpe_allocation)
    print("-"*80)
    print("Minimum Volatility Portfolio Allocation\n")
    print("Annualised Return: %", round(rp_min,2)*100)
    print("Annualised Volatility: %", round(sdp_min,2)*100)
    print("\n")
    print(min_vol_allocation)
    
    plt.figure(figsize=(10, 7))
    plt.scatter(results[0,:],results[1,:],c=results[2,:],cmap='YlGnBu', marker='o', s=10, alpha=0.3)
    plt.colorbar()
    plt.scatter(sdp,rp,marker='*',color='r',s=500, label='Maximum Sharpe ratio')
    plt.scatter(sdp_min,rp_min,marker='*',color='g',s=500, label='Minimum volatility')
    plt.title('Simulated Portfolio Optimization based on Efficient Frontier')
    plt.xlabel('Annualised Volatility')
    plt.ylabel('Annualised Returns')
    plt.legend(labelspacing=0.8)

# %%
display_simulated_ef_with_random(mean_returns, cov_matrix, num_portfolios, risk_free_rate)
# Out:
# --------------------------------------------------------------------------------
# Maximum Sharpe Ratio Portfolio Allocation
#
# Annualised Return: % 27.37
# Annualised Volatility: % 19.63
#
#
#             AUROPHARMA  GLAXO  GLENMARK  ZYDUSLIFE  WIPRO  TECHM  BSOFT  \
# allocation        3.77   3.49      5.27       0.36   3.32   4.76    5.0
#
#             HCLTECH  SUPRAJIT  BOSCHLTD  JAMNAAUTO  MAHSCOOTER   TCI   SCI  \
# allocation     7.19      6.54      1.76       8.96        8.32  4.59  1.04
#
#             AEGISCHEM  GPPL   NCC  KNRCON    LT  KALPATPOWR
# allocation      10.19  3.92  3.05   10.26  0.95        7.25
# --------------------------------------------------------------------------------
# Minimum Volatility Portfolio Allocation
#
# Annualised Return: % 19.0
# Annualised Volatility: % 17.0
#
#
#             AUROPHARMA  GLAXO  GLENMARK  ZYDUSLIFE  WIPRO  TECHM  BSOFT  \
# allocation        0.64  10.94      5.55       6.16   7.86   8.18   3.75
#
# ...

# %%
returns = np.sum(mean_returns*weights) *252
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\BODHIS~1\AppData\Local\Temp/ipykernel_283496/2538178004.py in <module>
# ----> 1 returns = np.sum(mean_returns*weights) *252
#
# NameError: name 'weights' is not defined

# %%
for i in xrange(500):
#         weights = np.random.random(20)
#         weights /= np.sum(weights)
#         weights_record.append(weights)
    xs = np.random.randint(-100, 100,20)
    s = sum(xs)
    if
    xs = [ i/s for i in xs ]
    xs = [x for x in xs if x != 0]
    weights = np.array(xs)
    weights_record.append(weights)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\BODHIS~1\AppData\Local\Temp/ipykernel_283496/4250079228.py in <module>
#       8     xs = [x for x in xs if x != 0]
#       9     weights = np.array(xs)
# ---> 10     weights_record.append(weights)
#
# NameError: name 'weights_record' is not defined
